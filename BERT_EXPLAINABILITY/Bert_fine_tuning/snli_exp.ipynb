# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 15.5 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 28.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 73.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.18.0
#     Uninstalling huggingface-hub-0.18.0:
#       Successfully uninstalled huggingface-hub-0.18.0
# ...

# %%
from datasets import load_dataset
import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import transformers
from transformers import AutoTokenizer
import torch
from transformers import BertForSequenceClassification, BertTokenizer, AutoModel

# %%
device = torch.device('cuda')

# %%
dataset = load_dataset("snli")
# Out:
# ...
# Downloading:   0%|          | 0.00/1.93k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26M [00:00<?, ?B/s]

# %%
ds_train = load_dataset("snli", split = 'train')
ds_test = load_dataset("snli", split = 'test')
ds_val = load_dataset("snli", split = 'validation')

# %%
print(ds_train)
print(ds_test)
print(ds_val)
# Out:
# Dataset({
#     features: ['premise', 'hypothesis', 'label'],
#     num_rows: 550152
# })
# Dataset({
#     features: ['premise', 'hypothesis', 'label'],
#     num_rows: 10000
# })
# Dataset({
#     features: ['premise', 'hypothesis', 'label'],
#     num_rows: 10000
# })

# %% [markdown]
# <i> Test and val size ~2% training data </i>

# %%
df_train = pd.DataFrame(ds_train)
df_test = pd.DataFrame(ds_test)
df_val = pd.DataFrame(ds_val)

# %%
df_train
# Out:
#                                                   premise  \
# 0       A person on a horse jumps over a broken down a...
# 1       A person on a horse jumps over a broken down a...
# 2       A person on a horse jumps over a broken down a...
# 3                   Children smiling and waving at camera
# 4                   Children smiling and waving at camera
# ...                                                   ...
# 550147                Four dirty and barefooted children.
# 550148                Four dirty and barefooted children.
# 550149  A man is surfing in a bodysuit in beautiful bl...
# 550150  A man is surfing in a bodysuit in beautiful bl...
# 550151  A man is surfing in a bodysuit in beautiful bl...
#
#                                                hypothesis  label
# 0       A person is training his horse for a competition.      1
# 1           A person is at a diner, ordering an omelette.      2
# 2                       A person is outdoors, on a horse.      0
# ...

# %% [markdown]
# ## TASK - Text Classification
# Predict if the Hypothesis is Neutral (1) , Contradiction (2) or Entailment (0)  with respect to the Premise

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels = 3)
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9db934a10d5f> in <cell line: 1>()
# ----> 1 model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels = 3)
#       2 tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
#
# NameError: name 'BertForSequenceClassification' is not defined

# %%
model.to('cuda')
model.cuda()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
# ...

# %%
input = tokenizer(["Hello world", "hi world", "hi bro"], padding = True)
model(input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-012d0a16cdc3> in <cell line: 1>()
# ----> 1 input = tokenizer(["Hello world", "hi world", "hi bro"], padding = True)
#       2 model(input)
#
# NameError: name 'tokenizer' is not defined

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from transformers import BertTokenizer, BertForSequenceClassification, AdamW

# Step 1: Prepare Your Data
# Define your custom dataset class here

# Step 2: Tokenization
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Step 3: Create Data Loaders
train_loader = DataLoader(ds_train, batch_size=32, shuffle=True)

# Step 4: Define Loss Function and Optimizer
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=2e-5)
# Step 6: Validation Loop (Optional)
# Evaluate your model on a validation set periodically
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Step 5: Fine-tuning Loop
for epoch in range(num_epochs):
    model.train()
    for batch in train_loader:
        optimizer.zero_grad()
        inputs, labels = batch
        outputs = model(**inputs)
        loss = loss_fn(outputs.logits, labels)
        loss.backward()
        optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-57914e882b71> in <cell line: 3>()
#       5     for batch in train_loader:
#       6         optimizer.zero_grad()
# ----> 7         inputs, labels = batch
#       8         outputs = model(**inputs)
#       9         loss = loss_fn(outputs.logits, labels)
#
# ValueError: too many values to unpack (expected 2)

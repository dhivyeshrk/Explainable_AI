# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: dill, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-2.14.6 dill-0.3.7 huggingface-hub-0.19.0 multiprocess-0.70.15

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 80.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 39.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.19.0
#     Uninstalling huggingface-hub-0.19.0:
#       Successfully uninstalled huggingface-hub-0.19.0
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0

# %%
from datasets import load_dataset
import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import transformers
from transformers import AutoTokenizer
import torch
from transformers import BertForSequenceClassification, BertTokenizer, AutoModel, AdamW, get_linear_schedule_with_warmup
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler,random_split
import itertools

# %%
device = torch.device('cuda')

# %%
dataset = load_dataset("snli")
# Out:
# Downloading builder script:   0%|          | 0.00/3.82k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.90k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/14.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.93k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26M [00:00<?, ?B/s]

# %%
ds_train = load_dataset("snli", split = 'train')
ds_test = load_dataset("snli", split = 'test')
ds_val = load_dataset("snli", split = 'validation')

# %%
print(ds_train)
print(ds_test)
print(ds_val)
# Out:
# Dataset({
#     features: ['premise', 'hypothesis', 'label'],
#     num_rows: 550152
# })
# Dataset({
#     features: ['premise', 'hypothesis', 'label'],
#     num_rows: 10000
# })
# Dataset({
#     features: ['premise', 'hypothesis', 'label'],
#     num_rows: 10000
# })

# %% [markdown]
# <i> Test and val size ~2% training data </i>

# %%
df_train = pd.DataFrame(ds_train)
df_test = pd.DataFrame(ds_test)
df_val = pd.DataFrame(ds_val)

# %%
df_train
# Out:
#                                                   premise  \
# 0       A person on a horse jumps over a broken down a...
# 1       A person on a horse jumps over a broken down a...
# 2       A person on a horse jumps over a broken down a...
# 3                   Children smiling and waving at camera
# 4                   Children smiling and waving at camera
# ...                                                   ...
# 550147                Four dirty and barefooted children.
# 550148                Four dirty and barefooted children.
# 550149  A man is surfing in a bodysuit in beautiful bl...
# 550150  A man is surfing in a bodysuit in beautiful bl...
# 550151  A man is surfing in a bodysuit in beautiful bl...
#
#                                                hypothesis  label
# 0       A person is training his horse for a competition.      1
# 1           A person is at a diner, ordering an omelette.      2
# 2                       A person is outdoors, on a horse.      0
# 3                       They are smiling at their parents      1
# 4                              There are children present      0
# ...                                                   ...    ...
# 550147           four kids won awards for 'cleanest feet'      2
# 550148  four homeless children had their shoes stolen,...      1
# 550149  A man in a bodysuit is competing in a surfing ...      1
# 550150  A man in a business suit is heading to a board...      2
# 550151  On the beautiful blue water there is a man in ...      0
#
# [550152 rows x 3 columns]
# Warning: total number of rows (550152) exceeds max_rows (20000). Limiting to first (20000) rows.
# Warning: total number of rows (550152) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
max_len = 0
count = 0
input_id_premise = []
input_id_hypothesis = []
for sentp, senth in zip(df_train['premise'], df_train['hypothesis']):

    # Tokenize the text and add `[CLS]` and `[SEP]` tokens.
    input_id1 = tokenizer.encode(sentp, add_special_tokens=True)
    input_id2 = tokenizer.encode(senth, add_special_tokens=True)

    # Update the maximum sentence length.
    max_len = max(max_len, max(len(input_id1), len(input_id2)))
    print(f"{count} rows completed")
    count += 1
print('Max sentence length: ', max_len)
# Out:
# Streaming output truncated to the last 5000 lines.
# 545153 rows completed
# 545154 rows completed
# 545155 rows completed
# 545156 rows completed
# 545157 rows completed
# 545158 rows completed
# 545159 rows completed
# 545160 rows completed
# 545161 rows completed
# 545162 rows completed
# 545163 rows completed
# 545164 rows completed
# 545165 rows completed
# 545166 rows completed
# 545167 rows completed
# 545168 rows completed
# 545169 rows completed
# 545170 rows completed
# 545171 rows completed
# 545172 rows completed
# 545173 rows completed
# 545174 rows completed
# 545175 rows completed
# 545176 rows completed
# 545177 rows completed
# 545178 rows completed
# 545179 rows completed
# 545180 rows completed
# 545181 rows completed
# 545182 rows completed
# 545183 rows completed
# 545184 rows completed
# 545185 rows completed
# 545186 rows completed
# 545187 rows completed
# 545188 rows completed
# 545189 rows completed
# 545190 rows completed
# 545191 rows completed
# 545192 rows completed
# 545193 rows completed
# 545194 rows completed
# 545195 rows completed
# 545196 rows completed
# 545197 rows completed
# 545198 rows completed
# 545199 rows completed
# 545200 rows completed
# 545201 rows completed
# 545202 rows completed
# 545203 rows completed
# 545204 rows completed
# 545205 rows completed
# 545206 rows completed
# 545207 rows completed
# 545208 rows completed
# 545209 rows completed
# 545210 rows completed
# 545211 rows completed
# 545212 rows completed
# 545213 rows completed
# 545214 rows completed
# 545215 rows completed
# 545216 rows completed
# 545217 rows completed
# 545218 rows completed
# 545219 rows completed
# 545220 rows completed
# 545221 rows completed
# 545222 rows completed
# 545223 rows completed
# 545224 rows completed
# 545225 rows completed
# 545226 rows completed
# 545227 rows completed
# 545228 rows completed
# 545229 rows completed
# 545230 rows completed
# 545231 rows completed
# 545232 rows completed
# 545233 rows completed
# 545234 rows completed
# 545235 rows completed
# 545236 rows completed
# 545237 rows completed
# 545238 rows completed
# 545239 rows completed
# 545240 rows completed
# 545241 rows completed
# 545242 rows completed
# 545243 rows completed
# 545244 rows completed
# 545245 rows completed
# 545246 rows completed
# 545247 rows completed
# 545248 rows completed
# 545249 rows completed
# 545250 rows completed
# 545251 rows completed
# 545252 rows completed
# 545253 rows completed
# 545254 rows completed
# 545255 rows completed
# 545256 rows completed
# 545257 rows completed
# 545258 rows completed
# 545259 rows completed
# 545260 rows completed
# 545261 rows completed
# 545262 rows completed
# 545263 rows completed
# 545264 rows completed
# 545265 rows completed
# 545266 rows completed
# 545267 rows completed
# 545268 rows completed
# 545269 rows completed
# 545270 rows completed
# 545271 rows completed
# 545272 rows completed
# 545273 rows completed
# 545274 rows completed
# 545275 rows completed
# 545276 rows completed
# 545277 rows completed
# 545278 rows completed
# 545279 rows completed
# 545280 rows completed
# 545281 rows completed
# 545282 rows completed
# 545283 rows completed
# 545284 rows completed
# 545285 rows completed
# 545286 rows completed
# 545287 rows completed
# 545288 rows completed
# 545289 rows completed
# 545290 rows completed
# 545291 rows completed
# 545292 rows completed
# 545293 rows completed
# 545294 rows completed
# 545295 rows completed
# 545296 rows completed
# 545297 rows completed
# 545298 rows completed
# 545299 rows completed
# 545300 rows completed
# 545301 rows completed
# 545302 rows completed
# 545303 rows completed
# 545304 rows completed
# 545305 rows completed
# 545306 rows completed
# 545307 rows completed
# 545308 rows completed
# 545309 rows completed
# 545310 rows completed
# 545311 rows completed
# 545312 rows completed
# 545313 rows completed
# 545314 rows completed
# 545315 rows completed
# 545316 rows completed
# 545317 rows completed
# 545318 rows completed
# 545319 rows completed
# 545320 rows completed
# 545321 rows completed
# 545322 rows completed
# 545323 rows completed
# 545324 rows completed
# 545325 rows completed
# 545326 rows completed
# 545327 rows completed
# 545328 rows completed
# 545329 rows completed
# 545330 rows completed
# 545331 rows completed
# 545332 rows completed
# 545333 rows completed
# 545334 rows completed
# 545335 rows completed
# 545336 rows completed
# 545337 rows completed
# 545338 rows completed
# 545339 rows completed
# 545340 rows completed
# 545341 rows completed
# 545342 rows completed
# 545343 rows completed
# 545344 rows completed
# 545345 rows completed
# 545346 rows completed
# 545347 rows completed
# 545348 rows completed
# 545349 rows completed
# 545350 rows completed
# 545351 rows completed
# 545352 rows completed
# 545353 rows completed
# 545354 rows completed
# 545355 rows completed
# 545356 rows completed
# 545357 rows completed
# 545358 rows completed
# 545359 rows completed
# 545360 rows completed
# 545361 rows completed
# 545362 rows completed
# 545363 rows completed
# 545364 rows completed
# 545365 rows completed
# 545366 rows completed
# 545367 rows completed
# 545368 rows completed
# 545369 rows completed
# 545370 rows completed
# 545371 rows completed
# 545372 rows completed
# 545373 rows completed
# 545374 rows completed
# 545375 rows completed
# 545376 rows completed
# 545377 rows completed
# 545378 rows completed
# 545379 rows completed
# 545380 rows completed
# 545381 rows completed
# 545382 rows completed
# 545383 rows completed
# 545384 rows completed
# 545385 rows completed
# 545386 rows completed
# 545387 rows completed
# 545388 rows completed
# 545389 rows completed
# 545390 rows completed
# 545391 rows completed
# 545392 rows completed
# 545393 rows completed
# 545394 rows completed
# 545395 rows completed
# 545396 rows completed
# 545397 rows completed
# 545398 rows completed
# 545399 rows completed
# 545400 rows completed
# 545401 rows completed
# 545402 rows completed
# 545403 rows completed
# 545404 rows completed
# 545405 rows completed
# 545406 rows completed
# 545407 rows completed
# 545408 rows completed
# 545409 rows completed
# 545410 rows completed
# 545411 rows completed
# 545412 rows completed
# 545413 rows completed
# 545414 rows completed
# 545415 rows completed
# 545416 rows completed
# 545417 rows completed
# 545418 rows completed
# 545419 rows completed
# 545420 rows completed
# 545421 rows completed
# 545422 rows completed
# 545423 rows completed
# 545424 rows completed
# 545425 rows completed
# 545426 rows completed
# 545427 rows completed
# 545428 rows completed
# 545429 rows completed
# 545430 rows completed
# 545431 rows completed
# 545432 rows completed
# 545433 rows completed
# 545434 rows completed
# 545435 rows completed
# 545436 rows completed
# 545437 rows completed
# 545438 rows completed
# 545439 rows completed
# 545440 rows completed
# 545441 rows completed
# 545442 rows completed
# 545443 rows completed
# 545444 rows completed
# 545445 rows completed
# 545446 rows completed
# 545447 rows completed
# 545448 rows completed
# 545449 rows completed
# 545450 rows completed
# 545451 rows completed
# 545452 rows completed
# 545453 rows completed
# 545454 rows completed
# 545455 rows completed
# 545456 rows completed
# 545457 rows completed
# 545458 rows completed
# 545459 rows completed
# 545460 rows completed
# 545461 rows completed
# 545462 rows completed
# 545463 rows completed
# 545464 rows completed
# 545465 rows completed
# 545466 rows completed
# 545467 rows completed
# 545468 rows completed
# 545469 rows completed
# 545470 rows completed
# 545471 rows completed
# 545472 rows completed
# 545473 rows completed
# 545474 rows completed
# 545475 rows completed
# 545476 rows completed
# 545477 rows completed
# 545478 rows completed
# 545479 rows completed
# 545480 rows completed
# 545481 rows completed
# 545482 rows completed
# 545483 rows completed
# 545484 rows completed
# 545485 rows completed
# 545486 rows completed
# 545487 rows completed
# 545488 rows completed
# 545489 rows completed
# 545490 rows completed
# 545491 rows completed
# 545492 rows completed
# 545493 rows completed
# 545494 rows completed
# 545495 rows completed
# 545496 rows completed
# 545497 rows completed
# 545498 rows completed
# 545499 rows completed
# 545500 rows completed
# 545501 rows completed
# 545502 rows completed
# 545503 rows completed
# 545504 rows completed
# 545505 rows completed
# 545506 rows completed
# 545507 rows completed
# 545508 rows completed
# 545509 rows completed
# 545510 rows completed
# 545511 rows completed
# 545512 rows completed
# 545513 rows completed
# 545514 rows completed
# 545515 rows completed
# 545516 rows completed
# 545517 rows completed
# 545518 rows completed
# 545519 rows completed
# 545520 rows completed
# 545521 rows completed
# 545522 rows completed
# 545523 rows completed
# 545524 rows completed
# 545525 rows completed
# 545526 rows completed
# 545527 rows completed
# 545528 rows completed
# 545529 rows completed
# 545530 rows completed
# 545531 rows completed
# 545532 rows completed
# 545533 rows completed
# 545534 rows completed
# 545535 rows completed
# 545536 rows completed
# 545537 rows completed
# 545538 rows completed
# 545539 rows completed
# 545540 rows completed
# 545541 rows completed
# 545542 rows completed
# 545543 rows completed
# 545544 rows completed
# 545545 rows completed
# 545546 rows completed
# 545547 rows completed
# 545548 rows completed
# 545549 rows completed
# 545550 rows completed
# 545551 rows completed
# 545552 rows completed
# 545553 rows completed
# 545554 rows completed
# 545555 rows completed
# 545556 rows completed
# 545557 rows completed
# 545558 rows completed
# 545559 rows completed
# 545560 rows completed
# 545561 rows completed
# 545562 rows completed
# 545563 rows completed
# 545564 rows completed
# 545565 rows completed
# 545566 rows completed
# 545567 rows completed
# 545568 rows completed
# 545569 rows completed
# 545570 rows completed
# 545571 rows completed
# 545572 rows completed
# 545573 rows completed
# 545574 rows completed
# 545575 rows completed
# 545576 rows completed
# 545577 rows completed
# 545578 rows completed
# 545579 rows completed
# 545580 rows completed
# 545581 rows completed
# 545582 rows completed
# 545583 rows completed
# 545584 rows completed
# 545585 rows completed
# 545586 rows completed
# 545587 rows completed
# 545588 rows completed
# 545589 rows completed
# 545590 rows completed
# 545591 rows completed
# 545592 rows completed
# 545593 rows completed
# 545594 rows completed
# 545595 rows completed
# 545596 rows completed
# 545597 rows completed
# 545598 rows completed
# 545599 rows completed
# 545600 rows completed
# 545601 rows completed
# 545602 rows completed
# 545603 rows completed
# 545604 rows completed
# 545605 rows completed
# 545606 rows completed
# 545607 rows completed
# 545608 rows completed
# 545609 rows completed
# 545610 rows completed
# 545611 rows completed
# 545612 rows completed
# 545613 rows completed
# 545614 rows completed
# 545615 rows completed
# 545616 rows completed
# 545617 rows completed
# 545618 rows completed
# 545619 rows completed
# 545620 rows completed
# 545621 rows completed
# 545622 rows completed
# 545623 rows completed
# 545624 rows completed
# 545625 rows completed
# 545626 rows completed
# 545627 rows completed
# 545628 rows completed
# 545629 rows completed
# 545630 rows completed
# 545631 rows completed
# 545632 rows completed
# 545633 rows completed
# 545634 rows completed
# 545635 rows completed
# 545636 rows completed
# 545637 rows completed
# 545638 rows completed
# 545639 rows completed
# 545640 rows completed
# 545641 rows completed
# 545642 rows completed
# 545643 rows completed
# 545644 rows completed
# 545645 rows completed
# 545646 rows completed
# 545647 rows completed
# 545648 rows completed
# 545649 rows completed
# 545650 rows completed
# 545651 rows completed
# 545652 rows completed
# 545653 rows completed
# 545654 rows completed
# 545655 rows completed
# 545656 rows completed
# 545657 rows completed
# 545658 rows completed
# 545659 rows completed
# 545660 rows completed
# 545661 rows completed
# 545662 rows completed
# 545663 rows completed
# 545664 rows completed
# 545665 rows completed
# 545666 rows completed
# 545667 rows completed
# 545668 rows completed
# 545669 rows completed
# 545670 rows completed
# 545671 rows completed
# 545672 rows completed
# 545673 rows completed
# 545674 rows completed
# 545675 rows completed
# 545676 rows completed
# 545677 rows completed
# 545678 rows completed
# 545679 rows completed
# 545680 rows completed
# 545681 rows completed
# 545682 rows completed
# 545683 rows completed
# 545684 rows completed
# 545685 rows completed
# 545686 rows completed
# 545687 rows completed
# 545688 rows completed
# 545689 rows completed
# 545690 rows completed
# 545691 rows completed
# 545692 rows completed
# 545693 rows completed
# 545694 rows completed
# 545695 rows completed
# 545696 rows completed
# 545697 rows completed
# 545698 rows completed
# 545699 rows completed
# 545700 rows completed
# 545701 rows completed
# 545702 rows completed
# 545703 rows completed
# 545704 rows completed
# 545705 rows completed
# 545706 rows completed
# 545707 rows completed
# 545708 rows completed
# 545709 rows completed
# 545710 rows completed
# 545711 rows completed
# 545712 rows completed
# 545713 rows completed
# 545714 rows completed
# 545715 rows completed
# 545716 rows completed
# 545717 rows completed
# 545718 rows completed
# 545719 rows completed
# 545720 rows completed
# 545721 rows completed
# 545722 rows completed
# 545723 rows completed
# 545724 rows completed
# 545725 rows completed
# 545726 rows completed
# 545727 rows completed
# 545728 rows completed
# 545729 rows completed
# 545730 rows completed
# 545731 rows completed
# 545732 rows completed
# 545733 rows completed
# 545734 rows completed
# 545735 rows completed
# 545736 rows completed
# 545737 rows completed
# 545738 rows completed
# 545739 rows completed
# 545740 rows completed
# 545741 rows completed
# 545742 rows completed
# 545743 rows completed
# 545744 rows completed
# 545745 rows completed
# 545746 rows completed
# 545747 rows completed
# 545748 rows completed
# 545749 rows completed
# 545750 rows completed
# 545751 rows completed
# 545752 rows completed
# 545753 rows completed
# 545754 rows completed
# 545755 rows completed
# 545756 rows completed
# 545757 rows completed
# 545758 rows completed
# 545759 rows completed
# 545760 rows completed
# 545761 rows completed
# 545762 rows completed
# 545763 rows completed
# 545764 rows completed
# 545765 rows completed
# 545766 rows completed
# 545767 rows completed
# 545768 rows completed
# 545769 rows completed
# 545770 rows completed
# 545771 rows completed
# 545772 rows completed
# 545773 rows completed
# 545774 rows completed
# 545775 rows completed
# 545776 rows completed
# 545777 rows completed
# 545778 rows completed
# 545779 rows completed
# 545780 rows completed
# 545781 rows completed
# 545782 rows completed
# 545783 rows completed
# 545784 rows completed
# 545785 rows completed
# 545786 rows completed
# 545787 rows completed
# 545788 rows completed
# 545789 rows completed
# 545790 rows completed
# 545791 rows completed
# 545792 rows completed
# 545793 rows completed
# 545794 rows completed
# 545795 rows completed
# 545796 rows completed
# 545797 rows completed
# 545798 rows completed
# 545799 rows completed
# 545800 rows completed
# 545801 rows completed
# 545802 rows completed
# 545803 rows completed
# 545804 rows completed
# 545805 rows completed
# 545806 rows completed
# 545807 rows completed
# 545808 rows completed
# 545809 rows completed
# 545810 rows completed
# 545811 rows completed
# 545812 rows completed
# 545813 rows completed
# 545814 rows completed
# 545815 rows completed
# 545816 rows completed
# 545817 rows completed
# 545818 rows completed
# 545819 rows completed
# 545820 rows completed
# 545821 rows completed
# 545822 rows completed
# 545823 rows completed
# 545824 rows completed
# 545825 rows completed
# 545826 rows completed
# 545827 rows completed
# 545828 rows completed
# 545829 rows completed
# 545830 rows completed
# 545831 rows completed
# 545832 rows completed
# 545833 rows completed
# 545834 rows completed
# 545835 rows completed
# 545836 rows completed
# 545837 rows completed
# 545838 rows completed
# 545839 rows completed
# 545840 rows completed
# 545841 rows completed
# 545842 rows completed
# 545843 rows completed
# 545844 rows completed
# 545845 rows completed
# 545846 rows completed
# 545847 rows completed
# 545848 rows completed
# 545849 rows completed
# 545850 rows completed
# 545851 rows completed
# 545852 rows completed
# 545853 rows completed
# 545854 rows completed
# 545855 rows completed
# 545856 rows completed
# 545857 rows completed
# 545858 rows completed
# 545859 rows completed
# 545860 rows completed
# 545861 rows completed
# 545862 rows completed
# 545863 rows completed
# 545864 rows completed
# 545865 rows completed
# 545866 rows completed
# 545867 rows completed
# 545868 rows completed
# 545869 rows completed
# 545870 rows completed
# 545871 rows completed
# 545872 rows completed
# 545873 rows completed
# 545874 rows completed
# 545875 rows completed
# 545876 rows completed
# 545877 rows completed
# 545878 rows completed
# 545879 rows completed
# 545880 rows completed
# 545881 rows completed
# 545882 rows completed
# 545883 rows completed
# 545884 rows completed
# 545885 rows completed
# 545886 rows completed
# 545887 rows completed
# 545888 rows completed
# 545889 rows completed
# 545890 rows completed
# 545891 rows completed
# 545892 rows completed
# 545893 rows completed
# 545894 rows completed
# 545895 rows completed
# 545896 rows completed
# 545897 rows completed
# 545898 rows completed
# 545899 rows completed
# 545900 rows completed
# 545901 rows completed
# 545902 rows completed
# 545903 rows completed
# 545904 rows completed
# 545905 rows completed
# 545906 rows completed
# 545907 rows completed
# 545908 rows completed
# 545909 rows completed
# 545910 rows completed
# 545911 rows completed
# 545912 rows completed
# 545913 rows completed
# 545914 rows completed
# 545915 rows completed
# 545916 rows completed
# 545917 rows completed
# 545918 rows completed
# 545919 rows completed
# 545920 rows completed
# 545921 rows completed
# 545922 rows completed
# 545923 rows completed
# 545924 rows completed
# 545925 rows completed
# 545926 rows completed
# 545927 rows completed
# 545928 rows completed
# 545929 rows completed
# 545930 rows completed
# 545931 rows completed
# 545932 rows completed
# 545933 rows completed
# 545934 rows completed
# 545935 rows completed
# 545936 rows completed
# 545937 rows completed
# 545938 rows completed
# 545939 rows completed
# 545940 rows completed
# 545941 rows completed
# 545942 rows completed
# 545943 rows completed
# 545944 rows completed
# 545945 rows completed
# 545946 rows completed
# 545947 rows completed
# 545948 rows completed
# 545949 rows completed
# 545950 rows completed
# 545951 rows completed
# 545952 rows completed
# 545953 rows completed
# 545954 rows completed
# 545955 rows completed
# 545956 rows completed
# 545957 rows completed
# 545958 rows completed
# 545959 rows completed
# 545960 rows completed
# 545961 rows completed
# 545962 rows completed
# 545963 rows completed
# 545964 rows completed
# 545965 rows completed
# 545966 rows completed
# 545967 rows completed
# 545968 rows completed
# 545969 rows completed
# 545970 rows completed
# 545971 rows completed
# 545972 rows completed
# 545973 rows completed
# 545974 rows completed
# 545975 rows completed
# 545976 rows completed
# 545977 rows completed
# 545978 rows completed
# 545979 rows completed
# 545980 rows completed
# 545981 rows completed
# 545982 rows completed
# 545983 rows completed
# 545984 rows completed
# 545985 rows completed
# 545986 rows completed
# 545987 rows completed
# 545988 rows completed
# 545989 rows completed
# 545990 rows completed
# 545991 rows completed
# 545992 rows completed
# 545993 rows completed
# 545994 rows completed
# 545995 rows completed
# 545996 rows completed
# 545997 rows completed
# 545998 rows completed
# 545999 rows completed
# 546000 rows completed
# 546001 rows completed
# 546002 rows completed
# 546003 rows completed
# 546004 rows completed
# 546005 rows completed
# 546006 rows completed
# 546007 rows completed
# 546008 rows completed
# 546009 rows completed
# 546010 rows completed
# 546011 rows completed
# 546012 rows completed
# 546013 rows completed
# 546014 rows completed
# 546015 rows completed
# 546016 rows completed
# 546017 rows completed
# 546018 rows completed
# 546019 rows completed
# 546020 rows completed
# 546021 rows completed
# 546022 rows completed
# 546023 rows completed
# 546024 rows completed
# 546025 rows completed
# 546026 rows completed
# 546027 rows completed
# 546028 rows completed
# 546029 rows completed
# 546030 rows completed
# 546031 rows completed
# 546032 rows completed
# 546033 rows completed
# 546034 rows completed
# 546035 rows completed
# 546036 rows completed
# 546037 rows completed
# 546038 rows completed
# 546039 rows completed
# 546040 rows completed
# 546041 rows completed
# 546042 rows completed
# 546043 rows completed
# 546044 rows completed
# 546045 rows completed
# 546046 rows completed
# 546047 rows completed
# 546048 rows completed
# 546049 rows completed
# 546050 rows completed
# 546051 rows completed
# 546052 rows completed
# 546053 rows completed
# 546054 rows completed
# 546055 rows completed
# 546056 rows completed
# 546057 rows completed
# 546058 rows completed
# 546059 rows completed
# 546060 rows completed
# 546061 rows completed
# 546062 rows completed
# 546063 rows completed
# 546064 rows completed
# 546065 rows completed
# 546066 rows completed
# 546067 rows completed
# 546068 rows completed
# 546069 rows completed
# 546070 rows completed
# 546071 rows completed
# 546072 rows completed
# 546073 rows completed
# 546074 rows completed
# 546075 rows completed
# 546076 rows completed
# 546077 rows completed
# 546078 rows completed
# 546079 rows completed
# 546080 rows completed
# 546081 rows completed
# 546082 rows completed
# 546083 rows completed
# 546084 rows completed
# 546085 rows completed
# 546086 rows completed
# 546087 rows completed
# 546088 rows completed
# 546089 rows completed
# 546090 rows completed
# 546091 rows completed
# 546092 rows completed
# 546093 rows completed
# 546094 rows completed
# 546095 rows completed
# 546096 rows completed
# 546097 rows completed
# 546098 rows completed
# 546099 rows completed
# 546100 rows completed
# 546101 rows completed
# 546102 rows completed
# 546103 rows completed
# 546104 rows completed
# 546105 rows completed
# 546106 rows completed
# 546107 rows completed
# 546108 rows completed
# 546109 rows completed
# 546110 rows completed
# 546111 rows completed
# 546112 rows completed
# 546113 rows completed
# 546114 rows completed
# 546115 rows completed
# 546116 rows completed
# 546117 rows completed
# 546118 rows completed
# 546119 rows completed
# 546120 rows completed
# 546121 rows completed
# 546122 rows completed
# 546123 rows completed
# 546124 rows completed
# 546125 rows completed
# 546126 rows completed
# 546127 rows completed
# 546128 rows completed
# 546129 rows completed
# 546130 rows completed
# 546131 rows completed
# 546132 rows completed
# 546133 rows completed
# 546134 rows completed
# 546135 rows completed
# 546136 rows completed
# 546137 rows completed
# 546138 rows completed
# 546139 rows completed
# 546140 rows completed
# 546141 rows completed
# 546142 rows completed
# 546143 rows completed
# 546144 rows completed
# 546145 rows completed
# 546146 rows completed
# 546147 rows completed
# 546148 rows completed
# 546149 rows completed
# 546150 rows completed
# 546151 rows completed
# 546152 rows completed
# 546153 rows completed
# 546154 rows completed
# 546155 rows completed
# 546156 rows completed
# 546157 rows completed
# 546158 rows completed
# 546159 rows completed
# 546160 rows completed
# 546161 rows completed
# 546162 rows completed
# 546163 rows completed
# 546164 rows completed
# 546165 rows completed
# 546166 rows completed
# 546167 rows completed
# 546168 rows completed
# 546169 rows completed
# 546170 rows completed
# 546171 rows completed
# 546172 rows completed
# 546173 rows completed
# 546174 rows completed
# 546175 rows completed
# 546176 rows completed
# 546177 rows completed
# 546178 rows completed
# 546179 rows completed
# 546180 rows completed
# 546181 rows completed
# 546182 rows completed
# 546183 rows completed
# 546184 rows completed
# 546185 rows completed
# 546186 rows completed
# 546187 rows completed
# 546188 rows completed
# 546189 rows completed
# 546190 rows completed
# 546191 rows completed
# 546192 rows completed
# 546193 rows completed
# 546194 rows completed
# 546195 rows completed
# 546196 rows completed
# 546197 rows completed
# 546198 rows completed
# 546199 rows completed
# 546200 rows completed
# 546201 rows completed
# 546202 rows completed
# 546203 rows completed
# 546204 rows completed
# 546205 rows completed
# 546206 rows completed
# 546207 rows completed
# 546208 rows completed
# 546209 rows completed
# 546210 rows completed
# 546211 rows completed
# 546212 rows completed
# 546213 rows completed
# 546214 rows completed
# 546215 rows completed
# 546216 rows completed
# 546217 rows completed
# 546218 rows completed
# 546219 rows completed
# 546220 rows completed
# 546221 rows completed
# 546222 rows completed
# 546223 rows completed
# 546224 rows completed
# 546225 rows completed
# 546226 rows completed
# 546227 rows completed
# 546228 rows completed
# 546229 rows completed
# 546230 rows completed
# 546231 rows completed
# 546232 rows completed
# 546233 rows completed
# 546234 rows completed
# 546235 rows completed
# 546236 rows completed
# 546237 rows completed
# 546238 rows completed
# 546239 rows completed
# 546240 rows completed
# 546241 rows completed
# 546242 rows completed
# 546243 rows completed
# 546244 rows completed
# 546245 rows completed
# 546246 rows completed
# 546247 rows completed
# 546248 rows completed
# 546249 rows completed
# 546250 rows completed
# 546251 rows completed
# 546252 rows completed
# 546253 rows completed
# 546254 rows completed
# 546255 rows completed
# 546256 rows completed
# 546257 rows completed
# 546258 rows completed
# 546259 rows completed
# 546260 rows completed
# 546261 rows completed
# 546262 rows completed
# 546263 rows completed
# 546264 rows completed
# 546265 rows completed
# 546266 rows completed
# 546267 rows completed
# 546268 rows completed
# 546269 rows completed
# 546270 rows completed
# 546271 rows completed
# 546272 rows completed
# 546273 rows completed
# 546274 rows completed
# 546275 rows completed
# 546276 rows completed
# 546277 rows completed
# 546278 rows completed
# 546279 rows completed
# 546280 rows completed
# 546281 rows completed
# 546282 rows completed
# 546283 rows completed
# 546284 rows completed
# 546285 rows completed
# 546286 rows completed
# 546287 rows completed
# 546288 rows completed
# 546289 rows completed
# 546290 rows completed
# 546291 rows completed
# 546292 rows completed
# 546293 rows completed
# 546294 rows completed
# 546295 rows completed
# 546296 rows completed
# 546297 rows completed
# 546298 rows completed
# 546299 rows completed
# 546300 rows completed
# 546301 rows completed
# 546302 rows completed
# 546303 rows completed
# 546304 rows completed
# 546305 rows completed
# 546306 rows completed
# 546307 rows completed
# 546308 rows completed
# 546309 rows completed
# 546310 rows completed
# 546311 rows completed
# 546312 rows completed
# 546313 rows completed
# 546314 rows completed
# 546315 rows completed
# 546316 rows completed
# 546317 rows completed
# 546318 rows completed
# 546319 rows completed
# 546320 rows completed
# 546321 rows completed
# 546322 rows completed
# 546323 rows completed
# 546324 rows completed
# 546325 rows completed
# 546326 rows completed
# 546327 rows completed
# 546328 rows completed
# 546329 rows completed
# 546330 rows completed
# 546331 rows completed
# 546332 rows completed
# 546333 rows completed
# 546334 rows completed
# 546335 rows completed
# 546336 rows completed
# 546337 rows completed
# 546338 rows completed
# 546339 rows completed
# 546340 rows completed
# 546341 rows completed
# 546342 rows completed
# 546343 rows completed
# 546344 rows completed
# 546345 rows completed
# 546346 rows completed
# 546347 rows completed
# 546348 rows completed
# 546349 rows completed
# 546350 rows completed
# 546351 rows completed
# 546352 rows completed
# 546353 rows completed
# 546354 rows completed
# 546355 rows completed
# 546356 rows completed
# 546357 rows completed
# 546358 rows completed
# 546359 rows completed
# 546360 rows completed
# 546361 rows completed
# 546362 rows completed
# 546363 rows completed
# 546364 rows completed
# 546365 rows completed
# 546366 rows completed
# 546367 rows completed
# 546368 rows completed
# 546369 rows completed
# 546370 rows completed
# 546371 rows completed
# 546372 rows completed
# 546373 rows completed
# 546374 rows completed
# 546375 rows completed
# 546376 rows completed
# 546377 rows completed
# 546378 rows completed
# 546379 rows completed
# 546380 rows completed
# 546381 rows completed
# 546382 rows completed
# 546383 rows completed
# 546384 rows completed
# 546385 rows completed
# 546386 rows completed
# 546387 rows completed
# 546388 rows completed
# 546389 rows completed
# 546390 rows completed
# 546391 rows completed
# 546392 rows completed
# 546393 rows completed
# 546394 rows completed
# 546395 rows completed
# 546396 rows completed
# 546397 rows completed
# 546398 rows completed
# 546399 rows completed
# 546400 rows completed
# 546401 rows completed
# 546402 rows completed
# 546403 rows completed
# 546404 rows completed
# 546405 rows completed
# 546406 rows completed
# 546407 rows completed
# 546408 rows completed
# 546409 rows completed
# 546410 rows completed
# 546411 rows completed
# 546412 rows completed
# 546413 rows completed
# 546414 rows completed
# 546415 rows completed
# 546416 rows completed
# 546417 rows completed
# 546418 rows completed
# 546419 rows completed
# 546420 rows completed
# 546421 rows completed
# 546422 rows completed
# 546423 rows completed
# 546424 rows completed
# 546425 rows completed
# 546426 rows completed
# 546427 rows completed
# 546428 rows completed
# 546429 rows completed
# 546430 rows completed
# 546431 rows completed
# 546432 rows completed
# 546433 rows completed
# 546434 rows completed
# 546435 rows completed
# 546436 rows completed
# 546437 rows completed
# 546438 rows completed
# 546439 rows completed
# 546440 rows completed
# 546441 rows completed
# 546442 rows completed
# 546443 rows completed
# 546444 rows completed
# 546445 rows completed
# 546446 rows completed
# 546447 rows completed
# 546448 rows completed
# 546449 rows completed
# 546450 rows completed
# 546451 rows completed
# 546452 rows completed
# 546453 rows completed
# 546454 rows completed
# 546455 rows completed
# 546456 rows completed
# 546457 rows completed
# 546458 rows completed
# 546459 rows completed
# 546460 rows completed
# 546461 rows completed
# 546462 rows completed
# 546463 rows completed
# 546464 rows completed
# 546465 rows completed
# 546466 rows completed
# 546467 rows completed
# 546468 rows completed
# 546469 rows completed
# 546470 rows completed
# 546471 rows completed
# 546472 rows completed
# 546473 rows completed
# 546474 rows completed
# 546475 rows completed
# 546476 rows completed
# 546477 rows completed
# 546478 rows completed
# 546479 rows completed
# 546480 rows completed
# 546481 rows completed
# 546482 rows completed
# 546483 rows completed
# 546484 rows completed
# 546485 rows completed
# 546486 rows completed
# 546487 rows completed
# 546488 rows completed
# 546489 rows completed
# 546490 rows completed
# 546491 rows completed
# 546492 rows completed
# 546493 rows completed
# 546494 rows completed
# 546495 rows completed
# 546496 rows completed
# 546497 rows completed
# 546498 rows completed
# 546499 rows completed
# 546500 rows completed
# 546501 rows completed
# 546502 rows completed
# 546503 rows completed
# 546504 rows completed
# 546505 rows completed
# 546506 rows completed
# 546507 rows completed
# 546508 rows completed
# 546509 rows completed
# 546510 rows completed
# 546511 rows completed
# 546512 rows completed
# 546513 rows completed
# 546514 rows completed
# 546515 rows completed
# 546516 rows completed
# 546517 rows completed
# 546518 rows completed
# 546519 rows completed
# 546520 rows completed
# 546521 rows completed
# 546522 rows completed
# 546523 rows completed
# 546524 rows completed
# 546525 rows completed
# 546526 rows completed
# 546527 rows completed
# 546528 rows completed
# 546529 rows completed
# 546530 rows completed
# 546531 rows completed
# 546532 rows completed
# 546533 rows completed
# 546534 rows completed
# 546535 rows completed
# 546536 rows completed
# 546537 rows completed
# 546538 rows completed
# 546539 rows completed
# 546540 rows completed
# 546541 rows completed
# 546542 rows completed
# 546543 rows completed
# 546544 rows completed
# 546545 rows completed
# 546546 rows completed
# 546547 rows completed
# 546548 rows completed
# 546549 rows completed
# 546550 rows completed
# 546551 rows completed
# 546552 rows completed
# 546553 rows completed
# 546554 rows completed
# 546555 rows completed
# 546556 rows completed
# 546557 rows completed
# 546558 rows completed
# 546559 rows completed
# 546560 rows completed
# 546561 rows completed
# 546562 rows completed
# 546563 rows completed
# 546564 rows completed
# 546565 rows completed
# 546566 rows completed
# 546567 rows completed
# 546568 rows completed
# 546569 rows completed
# 546570 rows completed
# 546571 rows completed
# 546572 rows completed
# 546573 rows completed
# 546574 rows completed
# 546575 rows completed
# 546576 rows completed
# 546577 rows completed
# 546578 rows completed
# 546579 rows completed
# 546580 rows completed
# 546581 rows completed
# 546582 rows completed
# 546583 rows completed
# 546584 rows completed
# 546585 rows completed
# 546586 rows completed
# 546587 rows completed
# 546588 rows completed
# 546589 rows completed
# 546590 rows completed
# 546591 rows completed
# 546592 rows completed
# 546593 rows completed
# 546594 rows completed
# 546595 rows completed
# 546596 rows completed
# 546597 rows completed
# 546598 rows completed
# 546599 rows completed
# 546600 rows completed
# 546601 rows completed
# 546602 rows completed
# 546603 rows completed
# 546604 rows completed
# 546605 rows completed
# 546606 rows completed
# 546607 rows completed
# 546608 rows completed
# 546609 rows completed
# 546610 rows completed
# 546611 rows completed
# 546612 rows completed
# 546613 rows completed
# 546614 rows completed
# 546615 rows completed
# 546616 rows completed
# 546617 rows completed
# 546618 rows completed
# 546619 rows completed
# 546620 rows completed
# 546621 rows completed
# 546622 rows completed
# 546623 rows completed
# 546624 rows completed
# 546625 rows completed
# 546626 rows completed
# 546627 rows completed
# 546628 rows completed
# 546629 rows completed
# 546630 rows completed
# 546631 rows completed
# 546632 rows completed
# 546633 rows completed
# 546634 rows completed
# 546635 rows completed
# 546636 rows completed
# 546637 rows completed
# 546638 rows completed
# 546639 rows completed
# 546640 rows completed
# 546641 rows completed
# 546642 rows completed
# 546643 rows completed
# 546644 rows completed
# 546645 rows completed
# 546646 rows completed
# 546647 rows completed
# 546648 rows completed
# 546649 rows completed
# 546650 rows completed
# 546651 rows completed
# 546652 rows completed
# 546653 rows completed
# 546654 rows completed
# 546655 rows completed
# 546656 rows completed
# 546657 rows completed
# 546658 rows completed
# 546659 rows completed
# 546660 rows completed
# 546661 rows completed
# 546662 rows completed
# 546663 rows completed
# 546664 rows completed
# 546665 rows completed
# 546666 rows completed
# 546667 rows completed
# 546668 rows completed
# 546669 rows completed
# 546670 rows completed
# 546671 rows completed
# 546672 rows completed
# 546673 rows completed
# 546674 rows completed
# 546675 rows completed
# 546676 rows completed
# 546677 rows completed
# 546678 rows completed
# 546679 rows completed
# 546680 rows completed
# 546681 rows completed
# 546682 rows completed
# 546683 rows completed
# 546684 rows completed
# 546685 rows completed
# 546686 rows completed
# 546687 rows completed
# 546688 rows completed
# 546689 rows completed
# 546690 rows completed
# 546691 rows completed
# 546692 rows completed
# 546693 rows completed
# 546694 rows completed
# 546695 rows completed
# 546696 rows completed
# 546697 rows completed
# 546698 rows completed
# 546699 rows completed
# 546700 rows completed
# 546701 rows completed
# 546702 rows completed
# 546703 rows completed
# 546704 rows completed
# 546705 rows completed
# 546706 rows completed
# 546707 rows completed
# 546708 rows completed
# 546709 rows completed
# 546710 rows completed
# 546711 rows completed
# 546712 rows completed
# 546713 rows completed
# 546714 rows completed
# 546715 rows completed
# 546716 rows completed
# 546717 rows completed
# 546718 rows completed
# 546719 rows completed
# 546720 rows completed
# 546721 rows completed
# 546722 rows completed
# 546723 rows completed
# 546724 rows completed
# 546725 rows completed
# 546726 rows completed
# 546727 rows completed
# 546728 rows completed
# 546729 rows completed
# 546730 rows completed
# 546731 rows completed
# 546732 rows completed
# 546733 rows completed
# 546734 rows completed
# 546735 rows completed
# 546736 rows completed
# 546737 rows completed
# 546738 rows completed
# 546739 rows completed
# 546740 rows completed
# 546741 rows completed
# 546742 rows completed
# 546743 rows completed
# 546744 rows completed
# 546745 rows completed
# 546746 rows completed
# 546747 rows completed
# 546748 rows completed
# 546749 rows completed
# 546750 rows completed
# 546751 rows completed
# 546752 rows completed
# 546753 rows completed
# 546754 rows completed
# 546755 rows completed
# 546756 rows completed
# 546757 rows completed
# 546758 rows completed
# 546759 rows completed
# 546760 rows completed
# 546761 rows completed
# 546762 rows completed
# 546763 rows completed
# 546764 rows completed
# 546765 rows completed
# 546766 rows completed
# 546767 rows completed
# 546768 rows completed
# 546769 rows completed
# 546770 rows completed
# 546771 rows completed
# 546772 rows completed
# 546773 rows completed
# 546774 rows completed
# 546775 rows completed
# 546776 rows completed
# 546777 rows completed
# 546778 rows completed
# 546779 rows completed
# 546780 rows completed
# 546781 rows completed
# 546782 rows completed
# 546783 rows completed
# 546784 rows completed
# 546785 rows completed
# 546786 rows completed
# 546787 rows completed
# 546788 rows completed
# 546789 rows completed
# 546790 rows completed
# 546791 rows completed
# 546792 rows completed
# 546793 rows completed
# 546794 rows completed
# 546795 rows completed
# 546796 rows completed
# 546797 rows completed
# 546798 rows completed
# 546799 rows completed
# 546800 rows completed
# 546801 rows completed
# 546802 rows completed
# 546803 rows completed
# 546804 rows completed
# 546805 rows completed
# 546806 rows completed
# 546807 rows completed
# 546808 rows completed
# 546809 rows completed
# 546810 rows completed
# 546811 rows completed
# 546812 rows completed
# 546813 rows completed
# 546814 rows completed
# 546815 rows completed
# 546816 rows completed
# 546817 rows completed
# 546818 rows completed
# 546819 rows completed
# 546820 rows completed
# 546821 rows completed
# 546822 rows completed
# 546823 rows completed
# 546824 rows completed
# 546825 rows completed
# 546826 rows completed
# 546827 rows completed
# 546828 rows completed
# 546829 rows completed
# 546830 rows completed
# 546831 rows completed
# 546832 rows completed
# 546833 rows completed
# 546834 rows completed
# 546835 rows completed
# 546836 rows completed
# 546837 rows completed
# 546838 rows completed
# 546839 rows completed
# 546840 rows completed
# 546841 rows completed
# 546842 rows completed
# 546843 rows completed
# 546844 rows completed
# 546845 rows completed
# 546846 rows completed
# 546847 rows completed
# 546848 rows completed
# 546849 rows completed
# 546850 rows completed
# 546851 rows completed
# 546852 rows completed
# 546853 rows completed
# 546854 rows completed
# 546855 rows completed
# 546856 rows completed
# 546857 rows completed
# 546858 rows completed
# 546859 rows completed
# 546860 rows completed
# 546861 rows completed
# 546862 rows completed
# 546863 rows completed
# 546864 rows completed
# 546865 rows completed
# 546866 rows completed
# 546867 rows completed
# 546868 rows completed
# 546869 rows completed
# 546870 rows completed
# 546871 rows completed
# 546872 rows completed
# 546873 rows completed
# 546874 rows completed
# 546875 rows completed
# 546876 rows completed
# 546877 rows completed
# 546878 rows completed
# 546879 rows completed
# 546880 rows completed
# 546881 rows completed
# 546882 rows completed
# 546883 rows completed
# 546884 rows completed
# 546885 rows completed
# 546886 rows completed
# 546887 rows completed
# 546888 rows completed
# 546889 rows completed
# 546890 rows completed
# 546891 rows completed
# 546892 rows completed
# 546893 rows completed
# 546894 rows completed
# 546895 rows completed
# 546896 rows completed
# 546897 rows completed
# 546898 rows completed
# 546899 rows completed
# 546900 rows completed
# 546901 rows completed
# 546902 rows completed
# 546903 rows completed
# 546904 rows completed
# 546905 rows completed
# 546906 rows completed
# 546907 rows completed
# 546908 rows completed
# 546909 rows completed
# 546910 rows completed
# 546911 rows completed
# 546912 rows completed
# 546913 rows completed
# 546914 rows completed
# 546915 rows completed
# 546916 rows completed
# 546917 rows completed
# 546918 rows completed
# 546919 rows completed
# 546920 rows completed
# 546921 rows completed
# 546922 rows completed
# 546923 rows completed
# 546924 rows completed
# 546925 rows completed
# 546926 rows completed
# 546927 rows completed
# 546928 rows completed
# 546929 rows completed
# 546930 rows completed
# 546931 rows completed
# 546932 rows completed
# 546933 rows completed
# 546934 rows completed
# 546935 rows completed
# 546936 rows completed
# 546937 rows completed
# 546938 rows completed
# 546939 rows completed
# 546940 rows completed
# 546941 rows completed
# 546942 rows completed
# 546943 rows completed
# 546944 rows completed
# 546945 rows completed
# 546946 rows completed
# 546947 rows completed
# 546948 rows completed
# 546949 rows completed
# 546950 rows completed
# 546951 rows completed
# 546952 rows completed
# 546953 rows completed
# 546954 rows completed
# 546955 rows completed
# 546956 rows completed
# 546957 rows completed
# 546958 rows completed
# 546959 rows completed
# 546960 rows completed
# 546961 rows completed
# 546962 rows completed
# 546963 rows completed
# 546964 rows completed
# 546965 rows completed
# 546966 rows completed
# 546967 rows completed
# 546968 rows completed
# 546969 rows completed
# 546970 rows completed
# 546971 rows completed
# 546972 rows completed
# 546973 rows completed
# 546974 rows completed
# 546975 rows completed
# 546976 rows completed
# 546977 rows completed
# 546978 rows completed
# 546979 rows completed
# 546980 rows completed
# 546981 rows completed
# 546982 rows completed
# 546983 rows completed
# 546984 rows completed
# 546985 rows completed
# 546986 rows completed
# 546987 rows completed
# 546988 rows completed
# 546989 rows completed
# 546990 rows completed
# 546991 rows completed
# 546992 rows completed
# 546993 rows completed
# 546994 rows completed
# 546995 rows completed
# 546996 rows completed
# 546997 rows completed
# 546998 rows completed
# 546999 rows completed
# 547000 rows completed
# 547001 rows completed
# 547002 rows completed
# 547003 rows completed
# 547004 rows completed
# 547005 rows completed
# 547006 rows completed
# 547007 rows completed
# 547008 rows completed
# 547009 rows completed
# 547010 rows completed
# 547011 rows completed
# 547012 rows completed
# 547013 rows completed
# 547014 rows completed
# 547015 rows completed
# 547016 rows completed
# 547017 rows completed
# 547018 rows completed
# 550043 rows completed
# 550044 rows completed
# 550045 rows completed
# 550046 rows completed
# 550047 rows completed
# 550048 rows completed
# 550049 rows completed
# 550050 rows completed
# 550051 rows completed
# 550052 rows completed
# 550053 rows completed
# 550054 rows completed
# 550055 rows completed
# 550056 rows completed
# 550057 rows completed
# 550058 rows completed
# 550059 rows completed
# 550060 rows completed
# 550061 rows completed
# 550062 rows completed
# 550063 rows completed
# 550064 rows completed
# 550065 rows completed
# 550066 rows completed
# 550067 rows completed
# 550068 rows completed
# 550069 rows completed
# 550070 rows completed
# 550071 rows completed
# 550072 rows completed
# 550073 rows completed
# 550074 rows completed
# 550075 rows completed
# 550076 rows completed
# 550077 rows completed
# 550078 rows completed
# 550079 rows completed
# 550080 rows completed
# 550081 rows completed
# 550082 rows completed
# 550083 rows completed
# 550084 rows completed
# 550085 rows completed
# 550086 rows completed
# 550087 rows completed
# 550088 rows completed
# 550089 rows completed
# 550090 rows completed
# 550091 rows completed
# 550092 rows completed
# 550093 rows completed
# 550094 rows completed
# 550095 rows completed
# 550096 rows completed
# 550097 rows completed
# 550098 rows completed
# 550099 rows completed
# 550100 rows completed
# 550101 rows completed
# 550102 rows completed
# 550103 rows completed
# 550104 rows completed
# 550105 rows completed
# 550106 rows completed
# 550107 rows completed
# 550108 rows completed
# 550109 rows completed
# 550110 rows completed
# 550111 rows completed
# 550112 rows completed
# 550113 rows completed
# 550114 rows completed
# 550115 rows completed
# 550116 rows completed
# 550117 rows completed
# 550118 rows completed
# 550119 rows completed
# 550120 rows completed
# 550121 rows completed
# 550122 rows completed
# 550123 rows completed
# 550124 rows completed
# 550125 rows completed
# 550126 rows completed
# 550127 rows completed
# 550128 rows completed
# 550129 rows completed
# 550130 rows completed
# 550131 rows completed
# 550132 rows completed
# 550133 rows completed
# 550134 rows completed
# 550135 rows completed
# 550136 rows completed
# 550137 rows completed
# 550138 rows completed
# 550139 rows completed
# 550140 rows completed
# 550141 rows completed
# 550142 rows completed
# 550143 rows completed
# 550144 rows completed
# 550145 rows completed
# 550146 rows completed
# 550147 rows completed
# 550148 rows completed
# 550149 rows completed
# 550150 rows completed
# 550151 rows completed
# Max sentence length:  88

# %% [markdown]
# ## TASK - Text Classification
# Predict if the Hypothesis is Neutral (1) , Contradiction (2) or Entailment (0)  with respect to the Premise

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels = 3)
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased", do_lower_case = True)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(f"Original : {df_train['premise'].iloc[0]}")
print(f"Original : {tokenizer.tokenize(df_train['premise'].iloc[0])}")
print('Token IDs: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(df_train['premise'].iloc[0])))
# Out:
# Original : A person on a horse jumps over a broken down airplane.
# Original : ['a', 'person', 'on', 'a', 'horse', 'jumps', 'over', 'a', 'broken', 'down', 'airplane', '.']
# Token IDs:  [1037, 2711, 2006, 1037, 3586, 14523, 2058, 1037, 3714, 2091, 13297, 1012]

# %%
input_ids = []
attention_masks = []

# For every tweet...
for tweet in df_train['premise'].to_list():
    # `encode_plus` will:
    #   (1) Tokenize the sentence.
    #   (2) Prepend the `[CLS]` token to the start.
    #   (3) Append the `[SEP]` token to the end.
    #   (4) Map tokens to their IDs.
    #   (5) Pad or truncate the sentence to `max_length`
    #   (6) Create attention masks for [PAD] tokens.
    encoded_dict = tokenizer.encode_plus(
                        tweet,                      # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = max_len,           # Pad & truncate all sentences.
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks.
                        return_tensors = 'pt',     # Return pytorch tensors.
                   )

    # Add the encoded sentence to the list.
    input_ids.append(encoded_dict['input_ids'])

    # And its attention mask (simply differentiates padding from non-padding).
    attention_masks.append(encoded_dict['attention_mask'])
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2614: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
input_ids = []
attention_masks = []

# For every tweet...
for tweet in df_train['premise'].to_list():
    # `encode_plus` will:
    #   (1) Tokenize the sentence.
    #   (2) Prepend the `[CLS]` token to the start.
    #   (3) Append the `[SEP]` token to the end.
    #   (4) Map tokens to their IDs.
    #   (5) Pad or truncate the sentence to `max_length`
    #   (6) Create attention masks for [PAD] tokens.
    encoded_dict = tokenizer.encode_plus(
                        tweet,                      # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = max_len,           # Pad & truncate all sentences.
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks.
                        return_tensors = 'pt',     # Return pytorch tensors.
                   )

    # Add the encoded sentence to the list.
    input_ids.append(encoded_dict['input_ids'])

    # And its attention mask (simply differentiates padding from non-padding).
    attention_masks.append(encoded_dict['attention_mask'])

# %%
input_ids = torch.tensor(torch.stack(input_ids))
attention_masks = torch.tensor(torch.stack(attention_masks))
# Out:
# <ipython-input-53-69fcfa9f42e2>:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   attention_masks = torch.tensor(torch.stack(attention_masks))

# %%
# Combine the training inputs into a TensorDataset.
labels = torch.tensor(df_train['label'])
dataset = TensorDataset(input_ids, attention_masks, labels)

# Create a 90-10 train-validation split.

# Calculate the number of samples to include in each set.
train_size = int(0.8 * len(dataset))
#val_size = int(0.2 * len(dataset))
val_size = len(dataset)  - train_size

# Divide the dataset by randomly selecting samples.
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

print('{:>5,} training samples'.format(train_size))
print('{:>5,} validation samples'.format(val_size))
# Out:
# 440,121 training samples
# 110,031 validation samples

# %%
# The DataLoader needs to know our batch size for training, so we specify it
# here. For fine-tuning BERT on a specific task, the authors recommend a batch
# size of 16 or 32.
batch_size = 32

# Create the DataLoaders for our training and validation sets.
# We'll take training samples in random order.
train_dataloader = DataLoader(
            train_dataset,  # The training samples.
            sampler = RandomSampler(train_dataset), # Select batches randomly
            batch_size = batch_size # Trains with this batch size.
        )

# For validation the order doesn't matter, so we'll just read them sequentially.
validation_dataloader = DataLoader(
            val_dataset, # The validation samples.
            sampler = SequentialSampler(val_dataset), # Pull out batches sequentially.
            batch_size = batch_size # Evaluate with this batch size.
        )

# %%
# Load BertForSequenceClassification, the pretrained BERT model with a single
# linear classification layer on top.
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased", # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = 3, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)

# if device == "cuda:0":
# # Tell pytorch to run this model on the GPU.
#     model = model.cuda()
model = model.to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
optimizer = AdamW(model.parameters(),
                  lr = 2e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Number of training epochs. The BERT authors recommend between 2 and 4.
# We chose to run for 4, but we'll see later that this may be over-fitting the
# training data.
epochs = 4

# Total number of training steps is [number of batches] x [number of epochs].
# (Note that this is not the same as the number of training samples).
total_steps = len(train_dataloader) * epochs

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)

# %%
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import random, time


seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)
training_stats = []

# Measure the total training time for the whole run.
total_t0 = time.time()

# For each epoch...
for epoch_i in range(0, epochs):

    # ========================================
    #               Training
    # ========================================
    # Perform one full pass over the training set.
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    # Measure how long the training epoch takes.
    t0 = time.time()
    total_train_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
        # Unpack this training batch from our dataloader.
        #
        # As we unpack the batch, we'll also copy each tensor to the device using the
        # `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids
        #   [1]: attention masks
        #   [2]: labels
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)
        optimizer.zero_grad()
        output = model(b_input_ids,
                             token_type_ids=None,
                             attention_mask=b_input_mask,
                             labels=b_labels)
        loss = output.loss
        total_train_loss += loss.item()
        # Perform a backward pass to calculate the gradients.
        loss.backward()
        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are
        # modified based on their gradients, the learning rate, etc.
        optimizer.step()
        # Update the learning rate.
        scheduler.step()

    # Calculate the average loss over all of the batches.
    avg_train_loss = total_train_loss / len(train_dataloader)

    # Measure how long this epoch took.
    training_time = format_time(time.time() - t0)
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(training_time))
    # ========================================
    #               Validation
    # ========================================
    # After the completion of each training epoch, measure our performance on
    # our validation set.
    print("")
    print("Running Validation...")
    t0 = time.time()
    # Put the model in evaluation mode--the dropout layers behave differently
    # during evaluation.
    model.eval()
    # Tracking variables
    total_eval_accuracy = 0
    best_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0
    # Evaluate data for one epoch
    for batch in validation_dataloader:
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)
        # Tell pytorch not to bother with constructing the compute graph during
        # the forward pass, since this is only needed for backprop (training).
        with torch.no_grad():
            output= model(b_input_ids,
                                   token_type_ids=None,
                                   attention_mask=b_input_mask,
                                   labels=b_labels)
        loss = output.loss
        total_eval_loss += loss.item()
        # Move logits and labels to CPU if we are using GPU
        logits = output.logits
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        # Calculate the accuracy for this batch of test sentences, and
        # accumulate it over all batches.
        total_eval_accuracy += flat_accuracy(logits, label_ids)
    # Report the final accuracy for this validation run.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))
    # Calculate the average loss over all of the batches.
    avg_val_loss = total_eval_loss / len(validation_dataloader)
    # Measure how long the validation run took.
    validation_time = format_time(time.time() - t0)
    if avg_val_accuracy > best_eval_accuracy:
        torch.save(model, 'bert_model')
        best_eval_accuracy = avg_val_accuracy
    #print("  Validation Loss: {0:.2f}".format(avg_val_loss))
    #print("  Validation took: {:}".format(validation_time))
    # Record all statistics from this epoch.
    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': avg_val_accuracy,
            'Training Time': training_time,
            'Validation Time': validation_time
        }
    )
print("")
print("Training complete!")

print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 4 ========
# Training...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-fe125c23e71f> in <cell line: 15>()
#      40         b_labels = batch[2].to(device)
#      41         optimizer.zero_grad()
# ---> 42         output = model(b_input_ids,
#      43                              token_type_ids=None,
#      44                              attention_mask=b_input_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1562         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1563
# -> 1564         outputs = self.bert(
#    1565             input_ids,
#    1566             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     965             raise ValueError("You have to specify either input_ids or inputs_embeds")
#     966
# --> 967         batch_size, seq_length = input_shape
#     968         device = input_ids.device if input_ids is not None else inputs_embeds.device
#     969
#
# ValueError: too many values to unpack (expected 2)

# %%
# import torch
# from torch.utils.data import DataLoader, Dataset
# from transformers import BertTokenizer, BertForSequenceClassificatio  n, AdamW

# # Step 1: Prepare Your Data
# # Define your custom dataset class here

# # Step 2: Tokenization
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# # Step 3: Create Data Loaders
# train_loader = DataLoader(ds_train, batch_size=32, shuffle=True)

# # Step 4: Define Loss Function and Optimizer
# model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
# loss_fn = torch.nn.CrossEntropyLoss()
# optimizer = AdamW(model.parameters(), lr=2e-5)
# # Step 6: Validation Loop (Optional)
# # Evaluate your model on a validation set periodically
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Step 5: Fine-tuning Loop
for epoch in range(num_epochs):
    model.train()
    for batch in train_loader:
        optimizer.zero_grad()
        inputs, labels = batch
        outputs = model(**inputs)
        loss = loss_fn(outputs.logits, labels)
        loss.backward()
        optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-57914e882b71> in <cell line: 3>()
#       5     for batch in train_loader:
#       6         optimizer.zero_grad()
# ----> 7         inputs, labels = batch
#       8         outputs = model(**inputs)
#       9         loss = loss_fn(outputs.logits, labels)
#
# ValueError: too many values to unpack (expected 2)
